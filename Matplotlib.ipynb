# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %% [markdown]
# ## simple Example

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##ploting using matplotlib
#plt scatter

plt.scatter(x,y, c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('test.png')

# %%
##plt plot
y=x*x
plt.plot(x,y,'y*-')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D diagram')
#plt.plot(x,y,'r*--', linestyle='dashed', linewidth=2, markersize=12)
# Out:
# Text(0.5, 1.0, '2D diagram')

# %%
##creating Subplots
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')
plt.subplot(2,2,3)
plt.plot(x,y,'b')
plt.subplot(2,2,4)
plt.plot(x,y,'yo')

# %%
x = np.arange(1,11)
y= 3 * x + 5
plt.title('Matplotlib demo')
plt.xlabel('X axis caption')
plt.ylabel('Y axis caption')
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
#Compute the x and y coordinate for points on a sine wave
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
plt.title("sine wave form")

#plot the points using matplotlib
plt.plot(x, y)
plt.show()

# %%
## Bar plots

x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]
plt.bar(x,y,align='center')
plt.bar(x2, y2, color='g')
plt.title('Bar Graph')
plt.ylabel('Y axis')
plt.ylabel('X axis')

plt.show()

# %% [markdown]
# # Histograms

# %%
a = np.array([22,87,5,45,45,6,82,49,52,47,63,20,58])
plt.hist(a)
plt.title("histogram")
plt.show()

# %% [markdown]
# # Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

#rectangular box plot
plt.boxplot(data, vert=True, patch_artist=True);

# %%
data
# Out:
# [array([-0.84363838, -0.04351035, -1.8010456 , -0.47325448,  0.68609621,
#          1.47315468,  0.94936156, -1.22857805,  0.00981755,  0.25023961,
#         -0.46192602,  0.07372987, -1.48380887, -0.52174546,  0.64713339,
#         -0.46452366, -0.27907958, -0.94410068,  1.0535803 , -0.73098366,
#         -1.35351856, -0.13029696, -3.31443233,  0.23661492, -1.1866508 ,
#          0.54602387, -0.43494954,  1.38478453, -1.15424842, -0.24840453,
#          1.22451394,  0.50834575,  1.34235968,  2.72691208, -1.18369011,
#          2.32193217, -1.18100732, -0.10336642, -0.27855762,  0.18102862,
#         -0.44634964,  0.07533473, -0.57460321,  1.85573374,  1.0667798 ,
#          2.48351214,  1.01262042,  2.06680081,  1.53280464,  0.45109569,
#         -0.63512581, -1.59495969,  0.8523471 ,  0.48963319,  0.38139265,
#         -0.38864604,  1.01260882,  1.15447368,  1.197776  , -0.09899463,
#          0.52396682, -2.5195788 ,  1.16523326, -0.71102402,  1.66153778,
# ...

# %%
type(data)
# Out:
# list

# %% [markdown]
# # Pie Chart

# %%
#data to plot
labels = 'python', 'JavaScript', 'Java', 'Ruby'
sizes = [215, 200, 150, 100]
colors = ['gold', 'red', 'lightcoral', 'lightskyblue']
explode = (0.3, 0, 0, 0) #explode 1st slice

#Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()
